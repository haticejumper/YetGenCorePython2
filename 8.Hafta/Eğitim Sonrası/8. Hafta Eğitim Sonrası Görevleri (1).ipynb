# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
import time
def  vki_hesaplama(kilo, boy):
    vki= kilo/(boy**2)
    return round (vki,1)
def değer_araligi(vki):
    if vki < 18.5:
        return "zayıf"
    elif  vki<=24.9:
        return "normal kilolu"
    elif vki<= 29.9:
        return "fazla kilolu"
    elif vki<=39.9:
        return "obez"
    elif vki >= 40:
        return "ileri obez"

def cikti_olustur(isim, yas, kilo, boy, vki, deger):
    kayit_tarihi= time.ctime(time.time())
    t1 = f"kullanıcı adı{isim}\n"
    t2 = f"kullanıcının yaş kilo boy bilgisi {yas}, {kilo}, {boy}\n"
    t3 = f"kullanıcının vücüt kitle indexi {vki}\n"
    t4 = f"değer aralığı {deger}\n"
    t5 = f"oluşturma tarihi {kayit_tarihi}\n"

    output = t1 + t2 + t3 + t4 + t5
    return output

def main():
    giris_sayisi= int(input("kaç kullanıcı verisi gireceksiniz"))
    for i in range(giris_sayisi):
        isim= input("isim soyisim")
        yas = int(input("yas:"))
        kilo = float(input("kilo:"))
        boy =float(input ("boy:"))
        vki = vki_hesaplama(kilo, boy)
        deger = değer_araligi(vki)
        output= cikti_olustur(isim,yas,kilo,boy,vki,deger)

        with open ("saglik.txt", "a") as f:
            f.write(output)
            f.write("*"*20)
            f.write("\n")
            print("kullanıcı kaydedildi.")

    print("verielr 'saglik.txt' dosyasındna kaydedildi.\n")
main()
# Out:
# kullanıcı kaydedildi.
# verielr 'saglik.txt' dosyasındna kaydedildi.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
import time 

menu = {
    "elma": 0.50,
    "armut": 0.75,
    "uzum":2.0,
    "cilek": 1.75,
    "muz": 2.,
    "kavun":2.15,
    "karpuz": 1.99
}

print("elmanin fiyati: ", menu["elma"])
print("kavunun fiyati:" , menu ["kavun"])

def display_menu():
     print("---------YETBAR MENU--------")
     for item in list(menu.keys()):
          print(f"{item.upper():<10} : {menu[item]} TL")

def tek_urun_fiyat_hesaplama(urun, adet):
    assert adet >= 0 , "Ürün adedi 0 ve 0'dan küçük olamaz."
    if urun not in list(menu.keys()):
         return None
    else :
         return menu[urun]*adet
satin_alinan_urunler = []
satin_alma_adedi= []
satin_alma_ucreti = []
def satin_alma():
    display_menu()
    print("Lütfen satin almak istediğiniz ürünü giriniz. Cikis yapmak için '0' i tuşlayinız")
    
    son_fiyat = 0
    while 1:
        eklenecek_urun = int(input("kaç adet eklemek istiyorsunuz?"))
        if  eklenecek_urun == "0":
              print("fiş kaydediliyor.")

        ekleme_adedi = int(input("kaç adet eklemek istiyorsunuz?"))
    
        fiyat = tek_urun_fiyat_hesaplama(eklenecek_urun, ekleme_adedi)
        if fiyat is None:
             print("yanlis bir giris yaptiniz.ürün eklemedi.")
        else:
             print(f"satin alma ucreti: {fiyat}.\nSatin almayi onaylamka için 'y' iptal etmek için 'n' giriniz.")
            
             check = input("satin almayi onayliyor öusunuz?")

             if check == "y":
                  print("Satin alim onalylandi.")
                  print("-"*40)

                  son_fiyat += fiyat

                  satin_alinan_urunler.append(eklenecek_urun)
                  satin_alma_adedi.append(ekleme_adedi)
                  print(f"ara toplam : {son_fiyat}")
             elif check =="n":
                  print("Satın alma işlemi iptal edildi.")
                  print("-"*40)
    return son_fiyat,satin_alinan_urunler,satin_alma_adedi
def main():
     print("YetBar'a hoş geldiniz!  \nMenüyü görüntülemek için '1' e , smoothie yapmak için '2'e basiniz.Cikmak icin '0' giriniz")
     program = None

     while 1:
          program = int(input("Tercihiniz:"))

          if program < 0 or program > 2:
               print("yanlis bir giriş yaptiniz.Lütfen tekrar deneyiniz.")
          elif program == 0:
               print("Çikiş yapiliyor. \nSağlikli günler dileriz.")
          elif program == 1:
               display_menu()
          elif program == 2:
               satin_alma_ucreti , satin_alinan_urunler, satin_alma_adedi == satin_alma()
               with open("kasa.txt","a") as f :
                    f.write(str(time.ctime(time.time())))
                    f.write("\n")
                    f.write(','.join(map(str,satin_alinan_urunler)))
                    f.write("\n")
                    f.write(','.join(map(str,satin_alma_adedi)))
                    f.write("\n")
                    f.write(f"Toplam: {satin_alma_ucreti}")     
                    f.write("\n") 
                    f.write("*"*20)
                    f.write("\n")   
               cikiş_kontrol = input("başka bir işlem yapmakn istiyor musunuz? (evet-hayir):")
               if cikiş_kontrol == "evet":
                    pass
               else:
                    print("\n\nTEŞEKKÜRLER")
                    break
main()
# Out:
# elmanin fiyati:  0.5
# kavunun fiyati: 2.15
# YetBar'a hoş geldiniz!
# Menüyü görüntülemek için '1' e , smoothie yapmak için '2'e basiniz.Cikmak icin '0' giriniz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 95
#      93                     print("\n\nTEŞEKKÜRLER")
#      94                     break
# ---> 95 main()
#
# Cell In[1], line 68, in main()
#      65 program = None
#      67 while 1:
# ---> 68      program = int(input("Tercihiniz:"))
#      70      if program < 0 or program > 2:
#      71           print("yanlis bir giriş yaptiniz.Lütfen tekrar deneyiniz.")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1187, in Kernel.raw_input(self, prompt)
#    1185     msg = "raw_input was called, but this frontend does not support input requests."
#    1186     raise StdinNotImplementedError(msg)
# -> 1187 return self._input_request(
#    1188     str(prompt),
#    1189     self._parent_ident["shell"],
#    1190     self.get_parent("shell"),
#    1191     password=False,
#    1192 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1230, in Kernel._input_request(self, prompt, ident, parent, password)
#    1227 except KeyboardInterrupt:
#    1228     # re-raise KeyboardInterrupt, to truncate traceback
#    1229     msg = "Interrupted by user"
# -> 1230     raise KeyboardInterrupt(msg) from None
#    1231 except Exception:
#    1232     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
